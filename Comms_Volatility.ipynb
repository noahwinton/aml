# %% [markdown]
# # Predicting Volatility Using Stock Fundamental Data

# %% [markdown]
# Anna Runci & Noah Winton

# %% [markdown]
# ## Setup & Imports

# %%
#!pip install tensorflow -q     
#!pip install -q -U keras-tuner #will always need to install if using Google Colab
#!pip install --upgrade pandas

# %%
#general libraries always needed
import pandas as pd
import numpy as np
import warnings
np.warnings = warnings
import math

#plotting required modules
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import FixedLocator, FixedFormatter

#sklearn clustering / unsupervised learning modules
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture
from sklearn.cluster import DBSCAN, KMeans
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.manifold import TSNE
from sklearn.neighbors import NearestNeighbors

#sklearn modules for preprocessing and transformation
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler, PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error

#TensorFlow required imports
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt

#give yourself the opportunity to visualize the pipeline and models
from sklearn import set_config
set_config(display='diagram')

from pathlib import Path

# %% [markdown]
# ## Function  Definition

# %%
#function provided that plots the learning curve for neural networks
def nn_plot_learning_curve( history ):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    ymin, ymax = [], []
    for x in history.history.keys():
        ymax.append( max(history.history[x]))
        ymin.append( min(history.history[x]))
    plt.gca().set_ylim(min(ymin)*.95, max(ymax)*1.05)
    plt.xlabel("EPOCHS")
    plt.show()

# %%
#function to verify the existence of a file in the current working directory and download it if not
import os,urllib, urllib.request, sys, tarfile
def downloadDataResource(file, sourcePath, compressed=None):
    if not os.path.isfile(file):
        try:
            urllib.request.urlretrieve(sourcePath+(compressed if compressed else file),(compressed if compressed else file))
            print("Downloaded", (compressed if compressed else file) )
            if compressed:
                ucomp = tarfile.open(compressed)
                ucomp.extractall()
                ucomp.close()
                print("File uncompressed.")
        except:
            print("ERROR: File", (compressed if compressed else file), "not found. Data source missing.")
    else:
        print("Data resource", file, "already downloaded.")

# %% [markdown]
# ## Source Data

# %% [markdown]
# We will be using compustat data downloaded from our Quant Finance Capstone Project, which contains monthly fundamental financial data of 5 industries within the Communications Services Sector.

# %%
df = pd.read_csv(r"C:\Users\annas\OneDrive - Villanova University\Spring 2024\MIS 3080\data.csv")
# Out:
# C:\Users\annas\AppData\Local\Temp\ipykernel_36672\1964343228.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\annas\OneDrive - Villanova University\Spring 2024\MIS 3080\data.csv")

# %%
df
# Out:
#            PDATE   GVKEY  PERMNO      DATE                     COMNAM TICKER  \
# 0      31DEC2005    1164   90284  20060131                  M C I INC   MCIP
# 1      30NOV2005    1164   90284  20051231                  M C I INC   MCIP
# 2      31OCT2005    1164   90284  20051130                  M C I INC   MCIP
# 3      30SEP2005    1164   90284  20051031                  M C I INC   MCIP
# 4      31AUG2005    1164   90284  20050930                  M C I INC   MCIP
# ...          ...     ...     ...       ...                        ...    ...
# 55875  30SEP2022  349530   17324  20221031  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55876  31AUG2022  349530   17324  20220930  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55877  31JUL2022  349530   17324  20220831  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55878  30JUN2022  349530   17324  20220731  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55879  31MAY2022  349530   17324  20220630  NEXTPLAY TECHNOLOGIES INC   NXTP
#
#            RET     MKTCAP   b_mkt   b_smb  ...       ROA        CF       ATG  \
# 0        4.66%        NaN  3.4004 -2.4477  ...  0.096023  0.008553  0.376621
# 1       -0.65%  $6,474.50  3.7807 -3.1377  ...  0.096023  0.008553  0.376621
# 2       -0.20%  $6,517.16  3.7723 -3.1330  ...  0.096023  0.008553  0.376621
# 3        0.39%  $6,530.28  4.0187 -3.3620  ...  0.096023  0.008553  0.376621
# 4       -0.90%  $8,332.52  4.4489 -3.6055  ...  0.096023  0.008553  0.376621
# ...        ...        ...     ...     ...  ...       ...       ...       ...
# 55875    5.40%     $26.59  1.5293  2.5532  ... -0.150632 -0.220876       NaN
# 55876  -20.11%     $24.01  1.5425  2.5463  ... -0.150632 -0.220876       NaN
# 55877   -7.43%     $30.05  1.5571  2.4969  ... -0.150632 -0.220876       NaN
# 55878  -17.57%     $33.96  1.5340  2.4427  ... -0.150632 -0.220876       NaN
# 55879   62.29%     $41.03  1.7750  2.7725  ... -0.150632 -0.220876       NaN
#
#              EY        PE       lev   CAratio   REratio PDATE_Start  PDATE_End
# 0     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 1     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 2     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 3     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 4     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# ...         ...       ...       ...       ...       ...         ...        ...
# 55875 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55876 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55877 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55878 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55879 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
#
# [55880 rows x 954 columns]

# %% [markdown]
# ## Prepare Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55880 entries, 0 to 55879
# Columns: 954 entries, PDATE to PDATE_End
# dtypes: float64(920), int64(13), object(21)
# memory usage: 406.7+ MB

# %%
#dropping blank columns 
df = df.dropna(axis=1, how='all')
df
# Out:
#            PDATE   GVKEY  PERMNO      DATE                     COMNAM TICKER  \
# 0      31DEC2005    1164   90284  20060131                  M C I INC   MCIP
# 1      30NOV2005    1164   90284  20051231                  M C I INC   MCIP
# 2      31OCT2005    1164   90284  20051130                  M C I INC   MCIP
# 3      30SEP2005    1164   90284  20051031                  M C I INC   MCIP
# 4      31AUG2005    1164   90284  20050930                  M C I INC   MCIP
# ...          ...     ...     ...       ...                        ...    ...
# 55875  30SEP2022  349530   17324  20221031  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55876  31AUG2022  349530   17324  20220930  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55877  31JUL2022  349530   17324  20220831  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55878  30JUN2022  349530   17324  20220731  NEXTPLAY TECHNOLOGIES INC   NXTP
# 55879  31MAY2022  349530   17324  20220630  NEXTPLAY TECHNOLOGIES INC   NXTP
#
#            RET     MKTCAP   b_mkt   b_smb  ...       ROA        CF       ATG  \
# 0        4.66%        NaN  3.4004 -2.4477  ...  0.096023  0.008553  0.376621
# 1       -0.65%  $6,474.50  3.7807 -3.1377  ...  0.096023  0.008553  0.376621
# 2       -0.20%  $6,517.16  3.7723 -3.1330  ...  0.096023  0.008553  0.376621
# 3        0.39%  $6,530.28  4.0187 -3.3620  ...  0.096023  0.008553  0.376621
# 4       -0.90%  $8,332.52  4.4489 -3.6055  ...  0.096023  0.008553  0.376621
# ...        ...        ...     ...     ...  ...       ...       ...       ...
# 55875    5.40%     $26.59  1.5293  2.5532  ... -0.150632 -0.220876       NaN
# 55876  -20.11%     $24.01  1.5425  2.5463  ... -0.150632 -0.220876       NaN
# 55877   -7.43%     $30.05  1.5571  2.4969  ... -0.150632 -0.220876       NaN
# 55878  -17.57%     $33.96  1.5340  2.4427  ... -0.150632 -0.220876       NaN
# 55879   62.29%     $41.03  1.7750  2.7725  ... -0.150632 -0.220876       NaN
#
#              EY        PE       lev   CAratio   REratio PDATE_Start  PDATE_End
# 0     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 1     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 2     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 3     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# 4     -0.003949  0.292810  0.502127  0.533001 -0.235873   31MAR2005  31MAR2006
# ...         ...       ...       ...       ...       ...         ...        ...
# 55875 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55876 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55877 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55878 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
# 55879 -4.224400 -0.261858  2.010769  0.338436 -0.394895   31MAY2022  31MAY2023
#
# [55880 rows x 583 columns]

# %%
column_names = df.columns.tolist()
column_names
# Out:
# ['PDATE',
#  'GVKEY',
#  'PERMNO',
#  'DATE',
#  'COMNAM',
#  'TICKER',
#  'RET',
#  'MKTCAP',
#  'b_mkt',
#  'b_smb',
#  'b_hml',
#  'aret',
#  'gsector',
#  'gind',
#  'gsubind',
#  'MKTCAP_1',
#  'datadate',
#  'fyear',
#  'tic',
#  'cusip',
#  'conm',
#  'ajex',
#  'fyr',
#  'acdo',
#  'aco',
#  'acodo',
#  'acominc',
#  'acox',
#  'acqao',
#  'acqcshi',
#  'acqgdwl',
#  'acqic',
#  'acqintan',
#  'acqinvt',
#  'acqppe',
#  'acqsc',
#  'act',
#  'afudcc',
#  'afudci',
#  'aldo',
#  'am',
#  'ano',
#  'ao',
#  'aocidergl',
#  'aociother',
#  'aocipen',
#  'aocisecgl',
#  'aodo',
#  'aol2',
#  'aoloch',
#  'aox',
#  'ap',
#  'apalch',
#  'aqa',
#  'aqc',
#  'aqd',
#  'aqeps',
#  'aqi',
#  'aqp',
#  'aqpl1',
#  'aqs',
#  'arce',
#  'arced',
#  'arceeps',
#  'at',
#  'aul3',
#  'bast',
#  'bastr',
#  'billexce',
#  'bkvlps',
#  'caps',
#  'capsft',
#  'capx',
#  'capxv',
#  'cb',
#  'cbi',
#  'cdvc',
#  'ceiexbill',
#  'ceq',
#  'ceql',
#  'ceqt',
#  'ch',
#  'che',
#  'chech',
#  'ci',
#  'cibegni',
#  'cicurr',
#  'cidergl',
#  'cimii',
#  'ciother',
#  'cipen',
#  'cisecgl',
#  'citotal',
#  'cld2',
#  'cld3',
#  'cld4',
#  'cld5',
#  'clg',
#  'cmp',
#  'cogs',
#  'cshfd',
#  'cshi',
#  'csho',
#  'cshpri',
#  'cshr',
#  'cshrc',
#  'cshrp',
#  'cshrso',
#  'cshrt',
#  'cshrw',
#  'cstk',
#  'cstkcv',
#  'cstke',
#  'dbi',
#  'dc',
#  'dclo',
#  'dcom',
#  'dcpstk',
#  'dcs',
#  'dcvsr',
#  'dcvsub',
#  'dcvt',
#  'dd',
#  'dd1',
#  'dd2',
#  'dd3',
#  'dd4',
#  'dd5',
#  'depc',
#  'derac',
#  'deralt',
#  'derhedgl',
#  'derlc',
#  'derllt',
#  'dfs',
#  'dfxa',
#  'diladj',
#  'dilavx',
#  'dlc',
#  'dlcch',
#  'dltis',
#  'dlto',
#  'dltp',
#  'dltr',
#  'dltt',
#  'dm',
#  'dn',
#  'do',
#  'donr',
#  'dp',
#  'dpacb',
#  'dpacc',
#  'dpacli',
#  'dpacls',
#  'dpacme',
#  'dpacnr',
#  'dpaco',
#  'dpact',
#  'dpc',
#  'dpvieb',
#  'dpvio',
#  'dpvir',
#  'drc',
#  'drlt',
#  'ds',
#  'dt',
#  'dtea',
#  'dted',
#  'dteeps',
#  'dtep',
#  'dudd',
#  'dv',
#  'dvc',
#  'dvintf',
#  'dvp',
#  'dvpa',
#  'dvpibb',
#  'dvt',
#  'dxd2',
#  'dxd3',
#  'dxd4',
#  'dxd5',
#  'ebit',
#  'ebitda',
#  'emp',
#  'epsfi',
#  'epsfx',
#  'epspi',
#  'epspx',
#  'esopct',
#  'esopdlt',
#  'esopnr',
#  'esopr',
#  'esopt',
#  'esub',
#  'esubc',
#  'exre',
#  'fatb',
#  'fatc',
#  'fate',
#  'fatl',
#  'fatn',
#  'fato',
#  'fatp',
#  'fca',
#  'fiao',
#  'fincf',
#  'fopo',
#  'fopox',
#  'fopt',
#  'fsrco',
#  'fsrct',
#  'fuseo',
#  'fuset',
#  'gdwl',
#  'gdwlam',
#  'gdwlia',
#  'gdwlid',
#  'gdwlieps',
#  'gdwlip',
#  'gla',
#  'glcea',
#  'glced',
#  'glceeps',
#  'glcep',
#  'gld',
#  'gleps',
#  'gliv',
#  'glp',
#  'gp',
#  'hedgegl',
#  'ib',
#  'ibadj',
#  'ibc',
#  'ibcom',
#  'ibmii',
#  'icapt',
#  'idit',
#  'intan',
#  'intano',
#  'intc',
#  'intpn',
#  'invch',
#  'invfg',
#  'invo',
#  'invrm',
#  'invt',
#  'invwip',
#  'ipti',
#  'irent',
#  'itcb',
#  'itcc',
#  'itci',
#  'ivaco',
#  'ivaeq',
#  'ivao',
#  'ivch',
#  'ivi',
#  'ivncf',
#  'ivst',
#  'ivstch',
#  'lco',
#  'lcox',
#  'lcoxdr',
#  'lct',
#  'lifr',
#  'lifrp',
#  'lno',
#  'lo',
#  'lol2',
#  'loxdr',
#  'lqpl1',
#  'lse',
#  'lt',
#  'lul3',
#  'mib',
#  'mibn',
#  'mibt',
#  'mii',
#  'mrc1',
#  'mrc2',
#  'mrc3',
#  'mrc4',
#  'mrc5',
#  'mrct',
#  'mrcta',
#  'msa',
#  'ni',
#  'niadj',
#  'nieci',
#  'nipfc',
#  'nipfp',
#  'nopi',
#  'nopio',
#  'np',
#  'nrtxt',
#  'nrtxtd',
#  'nrtxteps',
#  'oancf',
#  'ob',
#  'oiadp',
#  'oibdp',
#  'opeps',
#  'oprepsx',
#  'optca',
#  'optdr',
#  'optex',
#  'optexd',
#  'optfvgr',
#  'optgr',
#  'optlife',
#  'optosby',
#  'optosey',
#  'optprcby',
#  'optprcca',
#  'optprcex',
#  'optprcey',
#  'optprcgr',
#  'optprcwa',
#  'optrfr',
#  'optvol',
#  'pdvc',
#  'pi',
#  'pidom',
#  'pifo',
#  'pnca',
#  'pncad',
#  'pncaeps',
#  'pncia',
#  'pncid',
#  'pncieps',
#  'pncip',
#  'pncwia',
#  'pncwid',
#  'pncwieps',
#  'pncwip',
#  'pnrsho',
#  'ppegt',
#  'ppenb',
#  'ppenc',
#  'ppenli',
#  'ppenls',
#  'ppenme',
#  'ppennr',
#  'ppeno',
#  'ppent',
#  'ppevbb',
#  'ppeveb',
#  'ppevo',
#  'ppevr',
#  'prca',
#  'prcad',
#  'prcaeps',
#  'prsho',
#  'prstkc',
#  'prstkcc',
#  'prstkpc',
#  'pstk',
#  'pstkc',
#  'pstkl',
#  'pstkn',
#  'pstkr',
#  'pstkrv',
#  'rca',
#  'rcd',
#  'rceps',
#  'rcp',
#  'rdip',
#  'rdipa',
#  'rdipd',
#  'rdipeps',
#  're',
#  'rea',
#  'reajo',
#  'recch',
#  'recco',
#  'recd',
#  'rect',
#  'recta',
#  'rectr',
#  'recub',
#  'reuna',
#  'reunr',
#  'revt',
#  'rra',
#  'rrd',
#  'rreps',
#  'rrp',
#  'rstche',
#  'rstchelt',
#  'sale',
#  'salepfc',
#  'salepfp',
#  'scstkc',
#  'seq',
#  'seqo',
#  'seta',
#  'setd',
#  'seteps',
#  'setp',
#  'siv',
#  'spce',
#  'spced',
#  'spceeps',
#  'spi',
#  'spid',
#  'spieps',
#  'spioa',
#  'spiop',
#  'sppe',
#  'sppiv',
#  'spstkc',
#  'sstk',
#  'stkco',
#  'stkcpa',
#  'tdc',
#  'teq',
#  'tfva',
#  'tfvce',
#  'tfvl',
#  'tlcf',
#  'tstk',
#  'tstkc',
#  'tstkn',
#  'tstkp',
#  'txach',
#  'txbco',
#  'txbcof',
#  'txc',
#  'txdb',
#  'txdba',
#  'txdbca',
#  'txdbcl',
#  'txdc',
#  'txdfed',
#  'txdfo',
#  'txdi',
#  'txditc',
#  'txds',
#  'txfed',
#  'txfo',
#  'txndb',
#  'txndba',
#  'txndbl',
#  'txndbr',
#  'txo',
#  'txp',
#  'txpd',
#  'txr',
#  'txs',
#  'txt',
#  'txtubadjust',
#  'txtubbegin',
#  'txtubend',
#  'txtubmax',
#  'txtubmin',
#  'txtubposdec',
#  'txtubposinc',
#  'txtubpospdec',
#  'txtubpospinc',
#  'txtubsettle',
#  'txtubsoflimit',
#  'txtubtxtr',
#  'txtubxintbs',
#  'txtubxintis',
#  'txw',
#  'uaoloch',
#  'uaox',
#  'uapt',
#  'ucaps',
#  'uccons',
#  'uceq',
#  'ucustad',
#  'udcopres',
#  'udd',
#  'udfcc',
#  'udmb',
#  'udolt',
#  'udpco',
#  'udvp',
#  'ugi',
#  'uinvt',
#  'ulcm',
#  'ulco',
#  'uniami',
#  'unopinc',
#  'uois',
#  'uopi',
#  'updvp',
#  'upmpf',
#  'upmpfs',
#  'upmsubp',
#  'upstk',
#  'upstkc',
#  'upstksf',
#  'urect',
#  'urectr',
#  'urevub',
#  'usubdvp',
#  'usubpstk',
#  'utme',
#  'utxfed',
#  'wcap',
#  'wcapc',
#  'wcapch',
#  'wda',
#  'wdd',
#  'wdeps',
#  'wdp',
#  'xacc',
#  'xad',
#  'xdepl',
#  'xdp',
#  'xi',
#  'xido',
#  'xidoc',
#  'xint',
#  'xintd',
#  'xintopt',
#  'xlr',
#  'xnbi',
#  'xnins',
#  'xopr',
#  'xoptd',
#  'xopteps',
#  'xpp',
#  'xpr',
#  'xrd',
#  'xrdp',
#  'xrent',
#  'xsga',
#  'xuw',
#  'iid',
#  'exchg',
#  'cik',
#  'costat',
#  'fic',
#  'naicsh',
#  'sich',
#  'cshtr_c',
#  'dvpsp_c',
#  'dvpsx_c',
#  'prcc_c',
#  'prch_c',
#  'prcl_c',
#  'adjex_c',
#  'cshtr_f',
#  'dvpsp_f',
#  'dvpsx_f',
#  'mkvalt',
#  'prcc_f',
#  'prch_f',
#  'prcl_f',
#  'adjex_f',
#  'ggroup',
#  'dr',
#  'CR',
#  'SALEG',
#  'SALE_1',
#  'BE',
#  'ME',
#  'BtM',
#  'RE_P',
#  'Sale_P',
#  'FCF_P',
#  'RD_P',
#  'CF_P',
#  'E_P',
#  'EBITDA_EV',
#  'AT_1',
#  'GProf',
#  'ACC',
#  'AUE',
#  'ROA',
#  'CF',
#  'ATG',
#  'EY',
#  'PE',
#  'lev',
#  'CAratio',
#  'REratio',
#  'PDATE_Start',
#  'PDATE_End']

# %%
#drop columns with more than 5% missing values
